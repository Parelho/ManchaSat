# %% [markdown]
# # Overview
# We try here to improve another public U-Net model: https://www.kaggle.com/kmader/baseline-u-net-model-part-1 which shows how to extract the segmentation map for the ships, augment the images and train a simple DNN model to detect them. A few additional tweaks like balancing the ship-count out a little better have also been done.
#
# We are using a different loss function (closer to the competition scoring) and also fix and improve some visualisation functions and the submission itself.

# %% [markdown]
# ## Model Parameters
# We might want to adjust these later (or do some hyperparameter optimizations)

# %%
BATCH_SIZE = 48
EDGE_CROP = 16
GAUSSIAN_NOISE = 0.1
UPSAMPLE_MODE = 'SIMPLE'
# downsampling inside the network
NET_SCALING = (1, 1)
# downsampling in preprocessing
IMG_SCALING = (3, 3)
# number of validation images to use
VALID_IMG_COUNT = 900
# maximum number of steps_per_epoch in training
MAX_TRAIN_STEPS = 9
MAX_TRAIN_EPOCHS = 99
AUGMENT_BRIGHTNESS = False

# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from skimage.io import imread
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from skimage.segmentation import mark_boundaries
from skimage.util import montage
from skimage.morphology import binary_opening, disk, label
import gc; gc.enable() # memory is tight
import tensorflow as tf

montage_rgb = lambda x: np.stack([montage(x[:, :, :, i]) for i in range(x.shape[3])], -1)
ship_dir = os.path.expanduser('~/data/airbus-ship-detection')
train_image_dir = os.path.join(ship_dir, 'train_v2')
test_image_dir = os.path.join(ship_dir, 'test_v2')

def multi_rle_encode(img, **kwargs):
    '''
    Encode connected regions as separated masks
    '''
    labels = label(img)
    if img.ndim > 2:
        return [rle_encode(np.sum(labels==k, axis=2), **kwargs) for k in np.unique(labels[labels>0])]
    else:
        return [rle_encode(labels==k, **kwargs) for k in np.unique(labels[labels>0])]

# ref: https://www.kaggle.com/paulorzp/run-length-encode-and-decode
def rle_encode(img, min_max_threshold=1e-3, max_mean_threshold=None):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    if np.max(img) < min_max_threshold:
        return '' ## no need to encode if it's all zeros
    if max_mean_threshold and np.mean(img) > max_mean_threshold:
        return '' ## ignore overfilled mask
    pixels = img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle_decode(mask_rle, shape=(768, 768)):
    '''
    mask_rle: run-length as string formated (start length)
    shape: (height,width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction

def masks_as_image(in_mask_list):
    # Take the individual ship masks and create a single mask array for all ships
    all_masks = np.zeros((768, 768), dtype = np.uint8)
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks |= rle_decode(mask)
    return all_masks

def masks_as_color(in_mask_list):
    # Take the individual ship masks and create a color mask array for each ships
    all_masks = np.zeros((768, 768), dtype = np.float32)
    scale = lambda x: (len(in_mask_list)+x+1) / (len(in_mask_list)*2) ## scale the heatmap image to shift 
    for i,mask in enumerate(in_mask_list):
        if isinstance(mask, str):
            all_masks[:,:] += scale(i) * rle_decode(mask)
    return all_masks
# Out:
# 2025-08-22 14:00:53.546701: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-22 14:00:53.573956: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
masks = pd.read_csv(os.path.expanduser('~/data/airbus-ship-detection/train_ship_segmentations_v2.csv'))
not_empty = pd.notna(masks.EncodedPixels)
print(not_empty.sum(), 'masks in', masks[not_empty].ImageId.nunique(), 'images')
print((~not_empty).sum(), 'empty images in', masks.ImageId.nunique(), 'total images')
masks.head()
# Out:
# 81723 masks in 42556 images
# 150000 empty images in 192556 total images
#          ImageId                                      EncodedPixels
# 0  00003e153.jpg                                                NaN
# 1  0001124c7.jpg                                                NaN
# 2  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 3  000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 4  000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...

# %% [markdown]
# # Make sure encode/decode works
# Given the process
# $$  RLE_0 \stackrel{Decode}{\longrightarrow} \textrm{Image}_0 \stackrel{Encode}{\longrightarrow} RLE_1 \stackrel{Decode}{\longrightarrow} \textrm{Image}_1 $$
# We want to check if/that
# $ \textrm{Image}_0 \stackrel{?}{=} \textrm{Image}_1 $
# We could check the RLEs as well but that is more tedious. Also depending on how the objects have been labeled we might have different counts.

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (16, 5))
rle_0 = masks.query('ImageId=="00021ddc3.jpg"')['EncodedPixels']
img_0 = masks_as_image(rle_0)
ax1.imshow(img_0)
ax1.set_title('Mask as image')
rle_1 = multi_rle_encode(img_0)
img_1 = masks_as_image(rle_1)
ax2.imshow(img_1)
ax2.set_title('Re-encoded')
img_c = masks_as_color(rle_0)
ax3.imshow(img_c)
ax3.set_title('Masks in colors')
img_c = masks_as_color(rle_1)
ax4.imshow(img_c)
ax4.set_title('Re-encoded in colors')
print('Check Decoding->Encoding',
      'RLE_0:', len(rle_0), '->',
      'RLE_1:', len(rle_1))
print(np.sum(img_0 - img_1), 'error')
# Out:
# Check Decoding->Encoding RLE_0: 9 -> RLE_1: 4
# 0 error

# %% [markdown]
# # Split into training and validation groups
# We stratify by the number of boats appearing so we have nice balances in each set

# %%
masks['ships'] = masks['EncodedPixels'].map(lambda c_row: 1 if isinstance(c_row, str) else 0)
unique_img_ids = masks.groupby('ImageId').agg({'ships': 'sum'}).reset_index()
unique_img_ids['has_ship'] = unique_img_ids['ships'].map(lambda x: 1.0 if x>0 else 0.0)
unique_img_ids['has_ship_vec'] = unique_img_ids['has_ship'].map(lambda x: [x])
# some files are too small/corrupt
unique_img_ids['file_size_kb'] = unique_img_ids['ImageId'].map(lambda c_img_id: 
                                                               os.stat(os.path.join(train_image_dir, 
                                                                                    c_img_id)).st_size/1024)
unique_img_ids = unique_img_ids[unique_img_ids['file_size_kb'] > 50] # keep only +50kb files
unique_img_ids['file_size_kb'].hist()
masks.drop(['ships'], axis=1, inplace=True)
unique_img_ids.sample(7)
# Out:
#               ImageId  ships  has_ship has_ship_vec  file_size_kb
# 138781  b85dee469.jpg      0       0.0        [0.0]    204.656250
# 187463  f95b47316.jpg      0       0.0        [0.0]    126.157227
# 107505  8eefd1a5a.jpg      0       0.0        [0.0]    103.174805
# 102108  87c2e32ce.jpg      0       0.0        [0.0]    162.291992
# 166142  dd09da945.jpg      0       0.0        [0.0]    175.152344
# 98421   82ef577d6.jpg      0       0.0        [0.0]    207.789062
# 163875  d9fc7a452.jpg      0       0.0        [0.0]    166.907227

# %% [markdown]
# ### Examine Number of Ship Images
# Here we examine how often ships appear and replace the ones without any ships with 0

# %%
unique_img_ids['ships'].hist(bins=unique_img_ids['ships'].max())
# Out:
# <Axes: >

# %% [markdown]
# # Undersample Empty Images
# Here we undersample the empty images to get a better balanced group with more ships to try and segment

# %%
SAMPLES_PER_GROUP = 2000
balanced_train_df = unique_img_ids.groupby('ships').apply(lambda x: x.sample(SAMPLES_PER_GROUP) if len(x) > SAMPLES_PER_GROUP else x)
balanced_train_df['ships'].hist(bins=balanced_train_df['ships'].max()+1)
print(balanced_train_df.shape[0], 'masks')
# Out:
# 12788 masks
# /tmp/ipykernel_63952/539503715.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   balanced_train_df = unique_img_ids.groupby('ships').apply(lambda x: x.sample(SAMPLES_PER_GROUP) if len(x) > SAMPLES_PER_GROUP else x)

# %%
from sklearn.model_selection import train_test_split
train_ids, valid_ids = train_test_split(balanced_train_df, 
                 test_size = 0.2, 
                 stratify = balanced_train_df['ships'])
train_df = pd.merge(masks, train_ids)
valid_df = pd.merge(masks, valid_ids)
print(train_df.shape[0], 'training masks')
print(valid_df.shape[0], 'validation masks')
# Out:
# 35364 training masks
# 8838 validation masks

# %% [markdown]
# # Decode all the RLEs into Images
# We make a generator to produce batches of images

# %%
def make_image_gen(in_df, batch_size = BATCH_SIZE):
    all_batches = list(in_df.groupby('ImageId'))
    out_rgb = []
    out_mask = []
    while True:
        np.random.shuffle(all_batches)
        for c_img_id, c_masks in all_batches:
            rgb_path = os.path.join(train_image_dir, c_img_id)
            c_img = imread(rgb_path)
            c_mask = np.expand_dims(masks_as_image(c_masks['EncodedPixels'].values), -1)
            if IMG_SCALING is not None:
                c_img = c_img[::IMG_SCALING[0], ::IMG_SCALING[1]]
                c_mask = c_mask[::IMG_SCALING[0], ::IMG_SCALING[1]]
            out_rgb += [c_img]
            out_mask += [c_mask]
            if len(out_rgb)>=batch_size:
                yield np.stack(out_rgb, 0)/255.0, np.stack(out_mask, 0)
                out_rgb, out_mask=[], []

# %%
train_gen = make_image_gen(train_df)
train_x, train_y = next(train_gen)
print('x', train_x.shape, train_x.min(), train_x.max())
print('y', train_y.shape, train_y.min(), train_y.max())
# Out:
# x (48, 256, 256, 3) 0.0 1.0
# y (48, 256, 256, 1) 0 1

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (30, 10))
batch_rgb = montage_rgb(train_x)
batch_seg = montage(train_y[:, :, :, 0])
ax1.imshow(batch_rgb)
ax1.set_title('Images')
ax2.imshow(batch_seg)
ax2.set_title('Segmentations')
ax3.imshow(mark_boundaries(batch_rgb, 
                           batch_seg.astype(int)))
ax3.set_title('Outlined Ships')
fig.savefig('overview.png')

# %% [markdown]
# # Make the Validation Set

# %%
# %%time
valid_x, valid_y = next(make_image_gen(valid_df, VALID_IMG_COUNT))
print(valid_x.shape, valid_y.shape)
# Out:
# (900, 256, 256, 3) (900, 256, 256, 1)
# CPU times: user 3.51 s, sys: 779 ms, total: 4.29 s
# Wall time: 4.55 s

# %% [markdown]
# # Augment Data

# %%
from keras.preprocessing.image import ImageDataGenerator
dg_args = dict(featurewise_center = False, 
                  samplewise_center = False,
                  rotation_range = 45, 
                  width_shift_range = 0.1, 
                  height_shift_range = 0.1, 
                  shear_range = 0.01,
                  zoom_range = [0.9, 1.25],  
                  horizontal_flip = True, 
                  vertical_flip = True,
                  fill_mode = 'reflect',
                   data_format = 'channels_last')
# brightness can be problematic since it seems to change the labels differently from the images 
if AUGMENT_BRIGHTNESS:
    dg_args[' brightness_range'] = [0.5, 1.5]
image_gen = ImageDataGenerator(**dg_args)

if AUGMENT_BRIGHTNESS:
    dg_args.pop('brightness_range')
label_gen = ImageDataGenerator(**dg_args)

def create_aug_gen(in_gen, seed = None):
    np.random.seed(seed if seed is not None else np.random.choice(range(9999)))
    for in_x, in_y in in_gen:
        seed = np.random.choice(range(9999))
        # keep the seeds syncronized otherwise the augmentation to the images is different from the masks
        g_x = image_gen.flow(255*in_x, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)
        g_y = label_gen.flow(in_y, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)

        yield next(g_x)/255.0, next(g_y)

# %%
cur_gen = create_aug_gen(train_gen)
t_x, t_y = next(cur_gen)
print('x', t_x.shape, t_x.dtype, t_x.min(), t_x.max())
print('y', t_y.shape, t_y.dtype, t_y.min(), t_y.max())
# only keep first 9 samples to examine in detail
t_x = t_x[:9]
t_y = t_y[:9]
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 10))
ax1.imshow(montage_rgb(t_x), cmap='gray')
ax1.set_title('images')
ax2.imshow(montage(t_y[:, :, :, 0]), cmap='gray_r')
ax2.set_title('ships')
# Out:
# x (48, 256, 256, 3) float32 0.0 1.0
# y (48, 256, 256, 1) float32 0.0 1.0
# Text(0.5, 1.0, 'ships')

# %%
gc.collect()
# Out:
# 120

# %% [markdown]
# # Build a Model
# Here we use a slight deviation on the U-Net standard

# %%
from keras import models, layers
# Build U-Net model
def upsample_conv(filters, kernel_size, strides, padding):
    return layers.Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)
def upsample_simple(filters, kernel_size, strides, padding):
    return layers.UpSampling2D(strides)

if UPSAMPLE_MODE=='DECONV':
    upsample=upsample_conv
else:
    upsample=upsample_simple
    
input_img = layers.Input(t_x.shape[1:], name = 'RGB_Input')
pp_in_layer = input_img

if NET_SCALING is not None:
    pp_in_layer = layers.AvgPool2D(NET_SCALING)(pp_in_layer)
    
pp_in_layer = layers.GaussianNoise(GAUSSIAN_NOISE)(pp_in_layer)
pp_in_layer = layers.BatchNormalization()(pp_in_layer)

c1 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (pp_in_layer)
c1 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = layers.MaxPooling2D((2, 2)) (c1)

c2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = layers.MaxPooling2D((2, 2)) (c2)

c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = layers.MaxPooling2D((2, 2)) (c3)

c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = layers.MaxPooling2D(pool_size=(2, 2)) (c4)


c5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = upsample(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = layers.concatenate([u6, c4])
c6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = upsample(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = layers.concatenate([u7, c3])
c7 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = upsample(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = layers.concatenate([u8, c2])
c8 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = upsample(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = layers.concatenate([u9, c1], axis=3)
c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

d = layers.Conv2D(1, (1, 1), activation='sigmoid') (c9)
# d = layers.Cropping2D((EDGE_CROP, EDGE_CROP))(d)
# d = layers.ZeroPadding2D((EDGE_CROP, EDGE_CROP))(d)
if NET_SCALING is not None:
    d = layers.UpSampling2D(NET_SCALING)(d)

seg_model = models.Model(inputs=[input_img], outputs=[d])
seg_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  RGB_Input (InputLayer)      [(None, 256, 256, 3)]        0         []
#
#  average_pooling2d (Average  (None, 256, 256, 3)          0         ['RGB_Input[0][0]']
#  Pooling2D)
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)          0         ['average_pooling2d[0][0]']
#  ise)
#
#  batch_normalization (Batch  (None, 256, 256, 3)          12        ['gaussian_noise[0][0]']
#  Normalization)
#
#  conv2d (Conv2D)             (None, 256, 256, 8)          224       ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 8)          584       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 8)          0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 16)         1168      ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 16)         2320      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 16)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)           4640      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 32)           9248      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 32)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)           18496     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)           36928     ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 64)           0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)          73856     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)          147584    ['conv2d_8[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 128)          0         ['conv2d_9[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 32, 32, 192)          0         ['up_sampling2d[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 64)           110656    ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 64)           36928     ['conv2d_10[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 64)           0         ['conv2d_11[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 96)           0         ['up_sampling2d_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 32)           27680     ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 32)           9248      ['conv2d_12[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 32)         0         ['conv2d_13[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 48)         0         ['up_sampling2d_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 16)         6928      ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 16)         2320      ['conv2d_14[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 16)         0         ['conv2d_15[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 24)         0         ['up_sampling2d_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 8)          1736      ['concatenate_3[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 8)          584       ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 1)          9         ['conv2d_17[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 256, 256, 1)          0         ['conv2d_18[0][0]']
#  g2D)
#
# ==================================================================================================
# Total params: 491149 (1.87 MB)
# Trainable params: 491143 (1.87 MB)
# Non-trainable params: 6 (24.00 Byte)
# __________________________________________________________________________________________________
# 2025-08-22 14:01:04.588573: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.609303: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.613304: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.617160: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.619804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.623525: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.721099: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.722458: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.723672: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-22 14:01:04.724908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9728 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
import keras.backend as K
from keras.optimizers.legacy import Adam
from keras.losses import binary_crossentropy

# intersection over union
def IoU(y_true, y_pred, eps=1e-6):
    y_true = K.cast(y_true, "float32")
    y_pred = K.cast(y_pred, "float32")

    def _iou(a, b):
        intersection = K.sum(a * b, axis=[1, 2, 3])
        union = K.sum(a, axis=[1, 2, 3]) + K.sum(b, axis=[1, 2, 3]) - intersection
        return -K.mean((intersection + eps) / (union + eps), axis=0)

    # same empty-image logic as before, but TensorFlow-safe (no recursion)
    is_empty = K.equal(K.max(y_true), 0)
    return K.switch(is_empty, _iou(1 - y_true, 1 - y_pred), _iou(y_true, y_pred))

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('seg_model')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.33,
                                   patience=1, verbose=1, mode='min',
                                   min_delta=0.0001, cooldown=0, min_lr=1e-8)

early = EarlyStopping(monitor="val_loss", mode="min", verbose=2,
                      patience=20) # probably needs to be more patient, but kaggle time is limited

callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
def fit():
    seg_model.compile(optimizer=Adam(1e-3, decay=1e-6), loss=IoU, metrics=['binary_accuracy'])
    
    step_count = min(MAX_TRAIN_STEPS, train_df.shape[0]//BATCH_SIZE)
    aug_gen = create_aug_gen(make_image_gen(train_df))
    loss_history = [seg_model.fit_generator(aug_gen,
                                 steps_per_epoch=step_count,
                                 epochs=MAX_TRAIN_EPOCHS,
                                 validation_data=(valid_x, valid_y),
                                 callbacks=callbacks_list,
                                workers=1 # the generator is not very thread safe
                                           )]
    return loss_history

while True:
    loss_history = fit()
    if np.min([mh.history['val_loss'] for mh in loss_history]) < -0.2:
        break
# Out:
# /tmp/ipykernel_63952/244207219.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   loss_history = [seg_model.fit_generator(aug_gen,
# Epoch 1/99
# 2025-08-22 14:01:06.622782: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 9/9 [==============================] - ETA: 0s - loss: -0.0064 - binary_accuracy: 0.6062
# 2025-08-22 14:01:19.099623: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 1: val_loss improved from inf to -0.00585, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 15s 873ms/step - loss: -0.0064 - binary_accuracy: 0.6062 - val_loss: -0.0058 - val_binary_accuracy: 0.0066 - lr: 0.0010
# Epoch 2/99
# 9/9 [==============================] - ETA: 0s - loss: -0.0175 - binary_accuracy: 0.5797
# Epoch 2: val_loss improved from -0.00585 to -0.00617, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 596ms/step - loss: -0.0175 - binary_accuracy: 0.5797 - val_loss: -0.0062 - val_binary_accuracy: 0.0187 - lr: 0.0010
# Epoch 3/99
# 9/9 [==============================] - ETA: 0s - loss: -0.0480 - binary_accuracy: 0.5670
# Epoch 3: val_loss improved from -0.00617 to -0.00657, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 661ms/step - loss: -0.0480 - binary_accuracy: 0.5670 - val_loss: -0.0066 - val_binary_accuracy: 0.0339 - lr: 0.0010
# Epoch 4/99
# 9/9 [==============================] - ETA: 0s - loss: -0.0884 - binary_accuracy: 0.5881
# Epoch 4: val_loss improved from -0.00657 to -0.00768, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 663ms/step - loss: -0.0884 - binary_accuracy: 0.5881 - val_loss: -0.0077 - val_binary_accuracy: 0.0888 - lr: 0.0010
# Epoch 5/99
# 9/9 [==============================] - ETA: 0s - loss: -0.0945 - binary_accuracy: 0.5722
# Epoch 5: val_loss improved from -0.00768 to -0.01002, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 664ms/step - loss: -0.0945 - binary_accuracy: 0.5722 - val_loss: -0.0100 - val_binary_accuracy: 0.1638 - lr: 0.0010
# Epoch 6/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1258 - binary_accuracy: 0.7222
# Epoch 6: val_loss improved from -0.01002 to -0.02558, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 653ms/step - loss: -0.1258 - binary_accuracy: 0.7222 - val_loss: -0.0256 - val_binary_accuracy: 0.5646 - lr: 0.0010
# Epoch 7/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1446 - binary_accuracy: 0.9211
# Epoch 7: val_loss improved from -0.02558 to -0.03527, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 648ms/step - loss: -0.1446 - binary_accuracy: 0.9211 - val_loss: -0.0353 - val_binary_accuracy: 0.9889 - lr: 0.0010
# Epoch 8/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1313 - binary_accuracy: 0.9106
# Epoch 8: val_loss improved from -0.03527 to -0.06540, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 656ms/step - loss: -0.1313 - binary_accuracy: 0.9106 - val_loss: -0.0654 - val_binary_accuracy: 0.9779 - lr: 0.0010
# Epoch 9/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1110 - binary_accuracy: 0.7383
# Epoch 9: val_loss did not improve from -0.06540
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00033000001567415896.
# 9/9 [==============================] - 5s 656ms/step - loss: -0.1110 - binary_accuracy: 0.7383 - val_loss: -0.0489 - val_binary_accuracy: 0.5118 - lr: 0.0010
# Epoch 10/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1285 - binary_accuracy: 0.6193
# Epoch 10: val_loss improved from -0.06540 to -0.08065, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 666ms/step - loss: -0.1285 - binary_accuracy: 0.6193 - val_loss: -0.0807 - val_binary_accuracy: 0.6808 - lr: 3.3000e-04
# Epoch 11/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1456 - binary_accuracy: 0.7717
# Epoch 11: val_loss improved from -0.08065 to -0.09235, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 695ms/step - loss: -0.1456 - binary_accuracy: 0.7717 - val_loss: -0.0923 - val_binary_accuracy: 0.9791 - lr: 3.3000e-04
# Epoch 12/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1710 - binary_accuracy: 0.9831
# Epoch 12: val_loss improved from -0.09235 to -0.11512, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 704ms/step - loss: -0.1710 - binary_accuracy: 0.9831 - val_loss: -0.1151 - val_binary_accuracy: 0.9782 - lr: 3.3000e-04
# Epoch 13/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1455 - binary_accuracy: 0.9537
# Epoch 13: val_loss improved from -0.11512 to -0.12195, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 667ms/step - loss: -0.1455 - binary_accuracy: 0.9537 - val_loss: -0.1219 - val_binary_accuracy: 0.9910 - lr: 3.3000e-04
# Epoch 14/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1836 - binary_accuracy: 0.9509
# Epoch 14: val_loss improved from -0.12195 to -0.13581, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 672ms/step - loss: -0.1836 - binary_accuracy: 0.9509 - val_loss: -0.1358 - val_binary_accuracy: 0.9014 - lr: 3.3000e-04
# Epoch 15/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1789 - binary_accuracy: 0.9291
# Epoch 15: val_loss improved from -0.13581 to -0.13842, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 696ms/step - loss: -0.1789 - binary_accuracy: 0.9291 - val_loss: -0.1384 - val_binary_accuracy: 0.9404 - lr: 3.3000e-04
# Epoch 16/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2041 - binary_accuracy: 0.9558
# Epoch 16: val_loss improved from -0.13842 to -0.14970, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 689ms/step - loss: -0.2041 - binary_accuracy: 0.9558 - val_loss: -0.1497 - val_binary_accuracy: 0.9583 - lr: 3.3000e-04
# Epoch 17/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1714 - binary_accuracy: 0.9716
# Epoch 17: val_loss improved from -0.14970 to -0.16094, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 681ms/step - loss: -0.1714 - binary_accuracy: 0.9716 - val_loss: -0.1609 - val_binary_accuracy: 0.9800 - lr: 3.3000e-04
# Epoch 18/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1897 - binary_accuracy: 0.9796
# Epoch 18: val_loss improved from -0.16094 to -0.16508, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 697ms/step - loss: -0.1897 - binary_accuracy: 0.9796 - val_loss: -0.1651 - val_binary_accuracy: 0.9873 - lr: 3.3000e-04
# Epoch 19/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2142 - binary_accuracy: 0.9856
# Epoch 19: val_loss improved from -0.16508 to -0.18211, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 664ms/step - loss: -0.2142 - binary_accuracy: 0.9856 - val_loss: -0.1821 - val_binary_accuracy: 0.9887 - lr: 3.3000e-04
# Epoch 20/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1819 - binary_accuracy: 0.9831
# Epoch 20: val_loss did not improve from -0.18211
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010890000325161964.
# 9/9 [==============================] - 5s 668ms/step - loss: -0.1819 - binary_accuracy: 0.9831 - val_loss: -0.1678 - val_binary_accuracy: 0.9934 - lr: 3.3000e-04
# Epoch 21/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2034 - binary_accuracy: 0.9897
# Epoch 21: val_loss improved from -0.18211 to -0.18651, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 658ms/step - loss: -0.2034 - binary_accuracy: 0.9897 - val_loss: -0.1865 - val_binary_accuracy: 0.9897 - lr: 1.0890e-04
# Epoch 22/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1985 - binary_accuracy: 0.9898
# Epoch 22: val_loss improved from -0.18651 to -0.19251, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 665ms/step - loss: -0.1985 - binary_accuracy: 0.9898 - val_loss: -0.1925 - val_binary_accuracy: 0.9917 - lr: 1.0890e-04
# Epoch 23/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2245 - binary_accuracy: 0.9890
# Epoch 23: val_loss improved from -0.19251 to -0.20034, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 660ms/step - loss: -0.2245 - binary_accuracy: 0.9890 - val_loss: -0.2003 - val_binary_accuracy: 0.9911 - lr: 1.0890e-04
# Epoch 24/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2134 - binary_accuracy: 0.9885
# Epoch 24: val_loss improved from -0.20034 to -0.20698, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 642ms/step - loss: -0.2134 - binary_accuracy: 0.9885 - val_loss: -0.2070 - val_binary_accuracy: 0.9878 - lr: 1.0890e-04
# Epoch 25/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2087 - binary_accuracy: 0.9881
# Epoch 25: val_loss did not improve from -0.20698
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.5936999920522795e-05.
# 9/9 [==============================] - 5s 646ms/step - loss: -0.2087 - binary_accuracy: 0.9881 - val_loss: -0.2060 - val_binary_accuracy: 0.9905 - lr: 1.0890e-04
# Epoch 26/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2098 - binary_accuracy: 0.9873
# Epoch 26: val_loss improved from -0.20698 to -0.20805, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 660ms/step - loss: -0.2098 - binary_accuracy: 0.9873 - val_loss: -0.2081 - val_binary_accuracy: 0.9907 - lr: 3.5937e-05
# Epoch 27/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2114 - binary_accuracy: 0.9881
# Epoch 27: val_loss improved from -0.20805 to -0.21315, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 646ms/step - loss: -0.2114 - binary_accuracy: 0.9881 - val_loss: -0.2131 - val_binary_accuracy: 0.9890 - lr: 3.5937e-05
# Epoch 28/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2181 - binary_accuracy: 0.9881
# Epoch 28: val_loss did not improve from -0.21315
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.185920958960196e-05.
# 9/9 [==============================] - 5s 658ms/step - loss: -0.2181 - binary_accuracy: 0.9881 - val_loss: -0.2131 - val_binary_accuracy: 0.9911 - lr: 3.5937e-05
# Epoch 29/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2321 - binary_accuracy: 0.9903
# Epoch 29: val_loss improved from -0.21315 to -0.21579, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 684ms/step - loss: -0.2321 - binary_accuracy: 0.9903 - val_loss: -0.2158 - val_binary_accuracy: 0.9909 - lr: 1.1859e-05
# Epoch 30/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2256 - binary_accuracy: 0.9899
# Epoch 30: val_loss improved from -0.21579 to -0.21907, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 661ms/step - loss: -0.2256 - binary_accuracy: 0.9899 - val_loss: -0.2191 - val_binary_accuracy: 0.9897 - lr: 1.1859e-05
# Epoch 31/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2145 - binary_accuracy: 0.9878
# Epoch 31: val_loss improved from -0.21907 to -0.22077, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 661ms/step - loss: -0.2145 - binary_accuracy: 0.9878 - val_loss: -0.2208 - val_binary_accuracy: 0.9893 - lr: 1.1859e-05
# Epoch 32/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2399 - binary_accuracy: 0.9895
# Epoch 32: val_loss did not improve from -0.22077
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.913539212589967e-06.
# 9/9 [==============================] - 5s 647ms/step - loss: -0.2399 - binary_accuracy: 0.9895 - val_loss: -0.2206 - val_binary_accuracy: 0.9906 - lr: 1.1859e-05
# Epoch 33/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2266 - binary_accuracy: 0.9896
# Epoch 33: val_loss improved from -0.22077 to -0.22138, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 656ms/step - loss: -0.2266 - binary_accuracy: 0.9896 - val_loss: -0.2214 - val_binary_accuracy: 0.9908 - lr: 3.9135e-06
# Epoch 34/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2099 - binary_accuracy: 0.9897
# Epoch 34: val_loss improved from -0.22138 to -0.22235, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 679ms/step - loss: -0.2099 - binary_accuracy: 0.9897 - val_loss: -0.2223 - val_binary_accuracy: 0.9907 - lr: 3.9135e-06
# Epoch 35/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1974 - binary_accuracy: 0.9895
# Epoch 35: val_loss improved from -0.22235 to -0.22330, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 657ms/step - loss: -0.1974 - binary_accuracy: 0.9895 - val_loss: -0.2233 - val_binary_accuracy: 0.9905 - lr: 3.9135e-06
# Epoch 36/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2208 - binary_accuracy: 0.9887
# Epoch 36: val_loss improved from -0.22330 to -0.22466, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 645ms/step - loss: -0.2208 - binary_accuracy: 0.9887 - val_loss: -0.2247 - val_binary_accuracy: 0.9901 - lr: 3.9135e-06
# Epoch 37/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2086 - binary_accuracy: 0.9892
# Epoch 37: val_loss improved from -0.22466 to -0.22548, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 672ms/step - loss: -0.2086 - binary_accuracy: 0.9892 - val_loss: -0.2255 - val_binary_accuracy: 0.9899 - lr: 3.9135e-06
# Epoch 38/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2120 - binary_accuracy: 0.9897
# Epoch 38: val_loss improved from -0.22548 to -0.22574, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 646ms/step - loss: -0.2120 - binary_accuracy: 0.9897 - val_loss: -0.2257 - val_binary_accuracy: 0.9902 - lr: 3.9135e-06
# Epoch 39/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1973 - binary_accuracy: 0.9901
# Epoch 39: val_loss improved from -0.22574 to -0.22620, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 640ms/step - loss: -0.1973 - binary_accuracy: 0.9901 - val_loss: -0.2262 - val_binary_accuracy: 0.9902 - lr: 3.9135e-06
# Epoch 40/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2164 - binary_accuracy: 0.9908
# Epoch 40: val_loss improved from -0.22620 to -0.22737, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 658ms/step - loss: -0.2164 - binary_accuracy: 0.9908 - val_loss: -0.2274 - val_binary_accuracy: 0.9898 - lr: 3.9135e-06
# Epoch 41/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2285 - binary_accuracy: 0.9894
# Epoch 41: val_loss improved from -0.22737 to -0.22825, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 672ms/step - loss: -0.2285 - binary_accuracy: 0.9894 - val_loss: -0.2282 - val_binary_accuracy: 0.9895 - lr: 3.9135e-06
# Epoch 42/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2165 - binary_accuracy: 0.9887
# Epoch 42: val_loss improved from -0.22825 to -0.22871, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 662ms/step - loss: -0.2165 - binary_accuracy: 0.9887 - val_loss: -0.2287 - val_binary_accuracy: 0.9895 - lr: 3.9135e-06
# Epoch 43/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1890 - binary_accuracy: 0.9891
# Epoch 43: val_loss improved from -0.22871 to -0.22896, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 654ms/step - loss: -0.1890 - binary_accuracy: 0.9891 - val_loss: -0.2290 - val_binary_accuracy: 0.9896 - lr: 3.9135e-06
# Epoch 44/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2260 - binary_accuracy: 0.9898
# Epoch 44: val_loss improved from -0.22896 to -0.22932, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 658ms/step - loss: -0.2260 - binary_accuracy: 0.9898 - val_loss: -0.2293 - val_binary_accuracy: 0.9897 - lr: 3.9135e-06
# Epoch 45/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2203 - binary_accuracy: 0.9901
# Epoch 45: val_loss improved from -0.22932 to -0.22961, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 657ms/step - loss: -0.2203 - binary_accuracy: 0.9901 - val_loss: -0.2296 - val_binary_accuracy: 0.9898 - lr: 3.9135e-06
# Epoch 46/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2391 - binary_accuracy: 0.9905
# Epoch 46: val_loss improved from -0.22961 to -0.22986, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 681ms/step - loss: -0.2391 - binary_accuracy: 0.9905 - val_loss: -0.2299 - val_binary_accuracy: 0.9899 - lr: 3.9135e-06
# Epoch 47/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2357 - binary_accuracy: 0.9898
# Epoch 47: val_loss improved from -0.22986 to -0.23008, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 657ms/step - loss: -0.2357 - binary_accuracy: 0.9898 - val_loss: -0.2301 - val_binary_accuracy: 0.9900 - lr: 3.9135e-06
# Epoch 48/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2240 - binary_accuracy: 0.9896
# Epoch 48: val_loss improved from -0.23008 to -0.23054, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 647ms/step - loss: -0.2240 - binary_accuracy: 0.9896 - val_loss: -0.2305 - val_binary_accuracy: 0.9895 - lr: 3.9135e-06
# Epoch 49/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2156 - binary_accuracy: 0.9887
# Epoch 49: val_loss improved from -0.23054 to -0.23080, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 637ms/step - loss: -0.2156 - binary_accuracy: 0.9887 - val_loss: -0.2308 - val_binary_accuracy: 0.9895 - lr: 3.9135e-06
# Epoch 50/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2179 - binary_accuracy: 0.9906
# Epoch 50: val_loss improved from -0.23080 to -0.23086, saving model to seg_model_weights.best.hdf5
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.2914679791720119e-06.
# 9/9 [==============================] - 5s 648ms/step - loss: -0.2179 - binary_accuracy: 0.9906 - val_loss: -0.2309 - val_binary_accuracy: 0.9898 - lr: 3.9135e-06
# Epoch 51/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2123 - binary_accuracy: 0.9901
# Epoch 51: val_loss improved from -0.23086 to -0.23110, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 630ms/step - loss: -0.2123 - binary_accuracy: 0.9901 - val_loss: -0.2311 - val_binary_accuracy: 0.9898 - lr: 1.2915e-06
# Epoch 52/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2056 - binary_accuracy: 0.9889
# Epoch 52: val_loss improved from -0.23110 to -0.23123, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 640ms/step - loss: -0.2056 - binary_accuracy: 0.9889 - val_loss: -0.2312 - val_binary_accuracy: 0.9899 - lr: 1.2915e-06
# Epoch 53/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2079 - binary_accuracy: 0.9897
# Epoch 53: val_loss improved from -0.23123 to -0.23140, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 633ms/step - loss: -0.2079 - binary_accuracy: 0.9897 - val_loss: -0.2314 - val_binary_accuracy: 0.9899 - lr: 1.2915e-06
# Epoch 54/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2322 - binary_accuracy: 0.9893
# Epoch 54: val_loss improved from -0.23140 to -0.23151, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 657ms/step - loss: -0.2322 - binary_accuracy: 0.9893 - val_loss: -0.2315 - val_binary_accuracy: 0.9900 - lr: 1.2915e-06
# Epoch 55/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2074 - binary_accuracy: 0.9903
# Epoch 55: val_loss improved from -0.23151 to -0.23153, saving model to seg_model_weights.best.hdf5
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 4.2618441511876884e-07.
# 9/9 [==============================] - 5s 635ms/step - loss: -0.2074 - binary_accuracy: 0.9903 - val_loss: -0.2315 - val_binary_accuracy: 0.9899 - lr: 1.2915e-06
# Epoch 56/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2094 - binary_accuracy: 0.9914
# Epoch 56: val_loss improved from -0.23153 to -0.23166, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 653ms/step - loss: -0.2094 - binary_accuracy: 0.9914 - val_loss: -0.2317 - val_binary_accuracy: 0.9899 - lr: 4.2618e-07
# Epoch 57/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2166 - binary_accuracy: 0.9896
# Epoch 57: val_loss improved from -0.23166 to -0.23187, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 632ms/step - loss: -0.2166 - binary_accuracy: 0.9896 - val_loss: -0.2319 - val_binary_accuracy: 0.9899 - lr: 4.2618e-07
# Epoch 58/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2112 - binary_accuracy: 0.9903
# Epoch 58: val_loss improved from -0.23187 to -0.23193, saving model to seg_model_weights.best.hdf5
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.4064085661402716e-07.
# 9/9 [==============================] - 5s 656ms/step - loss: -0.2112 - binary_accuracy: 0.9903 - val_loss: -0.2319 - val_binary_accuracy: 0.9899 - lr: 4.2618e-07
# Epoch 59/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2351 - binary_accuracy: 0.9903
# Epoch 59: val_loss improved from -0.23193 to -0.23212, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 646ms/step - loss: -0.2351 - binary_accuracy: 0.9903 - val_loss: -0.2321 - val_binary_accuracy: 0.9899 - lr: 1.4064e-07
# Epoch 60/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2166 - binary_accuracy: 0.9892
# Epoch 60: val_loss improved from -0.23212 to -0.23226, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 640ms/step - loss: -0.2166 - binary_accuracy: 0.9892 - val_loss: -0.2323 - val_binary_accuracy: 0.9899 - lr: 1.4064e-07
# Epoch 61/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2199 - binary_accuracy: 0.9896
# Epoch 61: val_loss improved from -0.23226 to -0.23245, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 634ms/step - loss: -0.2199 - binary_accuracy: 0.9896 - val_loss: -0.2324 - val_binary_accuracy: 0.9899 - lr: 1.4064e-07
# Epoch 62/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2019 - binary_accuracy: 0.9901
# Epoch 62: val_loss improved from -0.23245 to -0.23250, saving model to seg_model_weights.best.hdf5
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 4.641148052542121e-08.
# 9/9 [==============================] - 5s 646ms/step - loss: -0.2019 - binary_accuracy: 0.9901 - val_loss: -0.2325 - val_binary_accuracy: 0.9899 - lr: 1.4064e-07
# Epoch 63/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2352 - binary_accuracy: 0.9899
# Epoch 63: val_loss improved from -0.23250 to -0.23261, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 630ms/step - loss: -0.2352 - binary_accuracy: 0.9899 - val_loss: -0.2326 - val_binary_accuracy: 0.9899 - lr: 4.6411e-08
# Epoch 64/99
# 9/9 [==============================] - ETA: 0s - loss: -0.1996 - binary_accuracy: 0.9896
# Epoch 64: val_loss did not improve from -0.23261
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.5315788104430796e-08.
# 9/9 [==============================] - 5s 632ms/step - loss: -0.1996 - binary_accuracy: 0.9896 - val_loss: -0.2323 - val_binary_accuracy: 0.9898 - lr: 4.6411e-08
# Epoch 65/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2347 - binary_accuracy: 0.9902
# Epoch 65: val_loss did not improve from -0.23261
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1e-08.
# 9/9 [==============================] - 5s 638ms/step - loss: -0.2347 - binary_accuracy: 0.9902 - val_loss: -0.2324 - val_binary_accuracy: 0.9899 - lr: 1.5316e-08
# Epoch 66/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2226 - binary_accuracy: 0.9899
# Epoch 66: val_loss did not improve from -0.23261
# 9/9 [==============================] - 5s 658ms/step - loss: -0.2226 - binary_accuracy: 0.9899 - val_loss: -0.2325 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 67/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2152 - binary_accuracy: 0.9892
# Epoch 67: val_loss improved from -0.23261 to -0.23261, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 627ms/step - loss: -0.2152 - binary_accuracy: 0.9892 - val_loss: -0.2326 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 68/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2262 - binary_accuracy: 0.9892
# Epoch 68: val_loss improved from -0.23261 to -0.23264, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 630ms/step - loss: -0.2262 - binary_accuracy: 0.9892 - val_loss: -0.2326 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 69/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2196 - binary_accuracy: 0.9892
# Epoch 69: val_loss improved from -0.23264 to -0.23267, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 630ms/step - loss: -0.2196 - binary_accuracy: 0.9892 - val_loss: -0.2327 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 70/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2509 - binary_accuracy: 0.9894
# Epoch 70: val_loss did not improve from -0.23267
# 9/9 [==============================] - 5s 637ms/step - loss: -0.2509 - binary_accuracy: 0.9894 - val_loss: -0.2327 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 71/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2289 - binary_accuracy: 0.9895
# Epoch 71: val_loss improved from -0.23267 to -0.23281, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 628ms/step - loss: -0.2289 - binary_accuracy: 0.9895 - val_loss: -0.2328 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 72/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2052 - binary_accuracy: 0.9879
# Epoch 72: val_loss did not improve from -0.23281
# 9/9 [==============================] - 5s 633ms/step - loss: -0.2052 - binary_accuracy: 0.9879 - val_loss: -0.2328 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 73/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2237 - binary_accuracy: 0.9903
# Epoch 73: val_loss improved from -0.23281 to -0.23288, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 630ms/step - loss: -0.2237 - binary_accuracy: 0.9903 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 74/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2028 - binary_accuracy: 0.9885
# Epoch 74: val_loss improved from -0.23288 to -0.23295, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 637ms/step - loss: -0.2028 - binary_accuracy: 0.9885 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 75/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2154 - binary_accuracy: 0.9892
# Epoch 75: val_loss did not improve from -0.23295
# 9/9 [==============================] - 5s 633ms/step - loss: -0.2154 - binary_accuracy: 0.9892 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 76/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2256 - binary_accuracy: 0.9895
# Epoch 76: val_loss did not improve from -0.23295
# 9/9 [==============================] - 5s 635ms/step - loss: -0.2256 - binary_accuracy: 0.9895 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 77/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2111 - binary_accuracy: 0.9893
# Epoch 77: val_loss did not improve from -0.23295
# 9/9 [==============================] - 5s 647ms/step - loss: -0.2111 - binary_accuracy: 0.9893 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 78/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2351 - binary_accuracy: 0.9896
# Epoch 78: val_loss did not improve from -0.23295
# 9/9 [==============================] - 5s 632ms/step - loss: -0.2351 - binary_accuracy: 0.9896 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 79/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2244 - binary_accuracy: 0.9897
# Epoch 79: val_loss did not improve from -0.23295
# 9/9 [==============================] - 5s 654ms/step - loss: -0.2244 - binary_accuracy: 0.9897 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 80/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2082 - binary_accuracy: 0.9886
# Epoch 80: val_loss did not improve from -0.23295
# 9/9 [==============================] - 5s 642ms/step - loss: -0.2082 - binary_accuracy: 0.9886 - val_loss: -0.2328 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 81/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2069 - binary_accuracy: 0.9893
# Epoch 81: val_loss did not improve from -0.23295
# 9/9 [==============================] - 5s 646ms/step - loss: -0.2069 - binary_accuracy: 0.9893 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 82/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2161 - binary_accuracy: 0.9897
# Epoch 82: val_loss did not improve from -0.23295
# 9/9 [==============================] - 5s 650ms/step - loss: -0.2161 - binary_accuracy: 0.9897 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 83/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2424 - binary_accuracy: 0.9895
# Epoch 83: val_loss improved from -0.23295 to -0.23307, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 637ms/step - loss: -0.2424 - binary_accuracy: 0.9895 - val_loss: -0.2331 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 84/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2167 - binary_accuracy: 0.9904
# Epoch 84: val_loss improved from -0.23307 to -0.23310, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 6s 680ms/step - loss: -0.2167 - binary_accuracy: 0.9904 - val_loss: -0.2331 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 85/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2361 - binary_accuracy: 0.9900
# Epoch 85: val_loss improved from -0.23310 to -0.23315, saving model to seg_model_weights.best.hdf5
# 9/9 [==============================] - 5s 639ms/step - loss: -0.2361 - binary_accuracy: 0.9900 - val_loss: -0.2332 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 86/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2041 - binary_accuracy: 0.9896
# Epoch 86: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 658ms/step - loss: -0.2041 - binary_accuracy: 0.9896 - val_loss: -0.2331 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 87/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2264 - binary_accuracy: 0.9905
# Epoch 87: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 659ms/step - loss: -0.2264 - binary_accuracy: 0.9905 - val_loss: -0.2331 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 88/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2315 - binary_accuracy: 0.9907
# Epoch 88: val_loss did not improve from -0.23315
# 9/9 [==============================] - 6s 687ms/step - loss: -0.2315 - binary_accuracy: 0.9907 - val_loss: -0.2331 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 89/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2050 - binary_accuracy: 0.9901
# Epoch 89: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 626ms/step - loss: -0.2050 - binary_accuracy: 0.9901 - val_loss: -0.2331 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 90/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2161 - binary_accuracy: 0.9906
# Epoch 90: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 635ms/step - loss: -0.2161 - binary_accuracy: 0.9906 - val_loss: -0.2331 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 91/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2250 - binary_accuracy: 0.9900
# Epoch 91: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 629ms/step - loss: -0.2250 - binary_accuracy: 0.9900 - val_loss: -0.2331 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 92/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2235 - binary_accuracy: 0.9900
# Epoch 92: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 625ms/step - loss: -0.2235 - binary_accuracy: 0.9900 - val_loss: -0.2330 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 93/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2155 - binary_accuracy: 0.9907
# Epoch 93: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 656ms/step - loss: -0.2155 - binary_accuracy: 0.9907 - val_loss: -0.2330 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 94/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2379 - binary_accuracy: 0.9896
# Epoch 94: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 622ms/step - loss: -0.2379 - binary_accuracy: 0.9896 - val_loss: -0.2330 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 95/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2189 - binary_accuracy: 0.9901
# Epoch 95: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 631ms/step - loss: -0.2189 - binary_accuracy: 0.9901 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 96/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2034 - binary_accuracy: 0.9894
# Epoch 96: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 625ms/step - loss: -0.2034 - binary_accuracy: 0.9894 - val_loss: -0.2328 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 97/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2117 - binary_accuracy: 0.9900
# Epoch 97: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 625ms/step - loss: -0.2117 - binary_accuracy: 0.9900 - val_loss: -0.2328 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 98/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2322 - binary_accuracy: 0.9891
# Epoch 98: val_loss did not improve from -0.23315
# 9/9 [==============================] - 6s 678ms/step - loss: -0.2322 - binary_accuracy: 0.9891 - val_loss: -0.2329 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08
# Epoch 99/99
# 9/9 [==============================] - ETA: 0s - loss: -0.2141 - binary_accuracy: 0.9883
# Epoch 99: val_loss did not improve from -0.23315
# 9/9 [==============================] - 5s 630ms/step - loss: -0.2141 - binary_accuracy: 0.9883 - val_loss: -0.2328 - val_binary_accuracy: 0.9898 - lr: 1.0000e-08

# %%
def show_loss(loss_history):
    epochs = np.concatenate([mh.epoch for mh in loss_history])
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(22, 10))
    
    _ = ax1.plot(epochs, np.concatenate([mh.history['loss'] for mh in loss_history]), 'b-',
                 epochs, np.concatenate([mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')
    
    _ = ax2.plot(epochs, np.concatenate([mh.history['binary_accuracy'] for mh in loss_history]), 'b-',
                 epochs, np.concatenate([mh.history['val_binary_accuracy'] for mh in loss_history]), 'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('Binary Accuracy (%)')

show_loss(loss_history)

# %%
seg_model.load_weights(weight_path)
seg_model.save('seg_model.h5')
# Out:
# /home/vinicius/anaconda3/envs/tf-gpu/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pred_y = seg_model.predict(valid_x)
print(pred_y.shape, pred_y.min(axis=0).max(), pred_y.max(axis=0).min(), pred_y.mean())
# Out:
# 29/29 [==============================] - 1s 38ms/step
# (900, 256, 256, 1) 0.0018599703 0.0009836415 0.011410747

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 6))
ax.hist(pred_y.ravel(), np.linspace(0, 1, 20))
ax.set_xlim(0, 1)
ax.set_yscale('log')

# %% [markdown]
# # Prepare Full Resolution Model
# Here we account for the scaling so everything can happen in the model itself

# %%
if IMG_SCALING is not None:
    fullres_model = models.Sequential()
    fullres_model.add(layers.AvgPool2D(IMG_SCALING, input_shape = (None, None, 3)))
    fullres_model.add(seg_model)
    fullres_model.add(layers.UpSampling2D(IMG_SCALING))
else:
    fullres_model = seg_model
fullres_model.save('fullres_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# from tensorflow.keras.models import load_model

# fullres_model = load_model("./seg_model_weights.best.hdf5.h5")

# %% [markdown]
# # Visualize predictions

# %%
def raw_prediction(img, path=test_image_dir):
    c_img = imread(os.path.join(path, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    cur_seg = fullres_model.predict(c_img)[0]
    return cur_seg, c_img[0]

def smooth(cur_seg):
    return binary_opening(cur_seg>0.99, np.expand_dims(disk(2), -1))

def predict(img, path=test_image_dir):
    cur_seg, c_img = raw_prediction(img, path=path)
    return smooth(cur_seg), c_img

## Get a sample of each group of ship count
samples = valid_df.groupby('ships').apply(lambda x: x.sample(1))
fig, m_axs = plt.subplots(samples.shape[0], 4, figsize = (15, samples.shape[0]*4))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2, ax3, ax4), c_img_name in zip(m_axs, samples.ImageId.values):
    first_seg, first_img = raw_prediction(c_img_name, train_image_dir)
    ax1.imshow(first_img)
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
    ax2.set_title('Model Prediction')
    reencoded = masks_as_color(multi_rle_encode(smooth(first_seg)[:, :, 0]))
    ax3.imshow(reencoded)
    ax3.set_title('Prediction Masks')
    ground_truth = masks_as_color(masks.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels'])
    ax4.imshow(ground_truth)
    ax4.set_title('Ground Truth')
    
fig.savefig('validation.png')
# Out:
# /tmp/ipykernel_63952/133765364.py:15: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   samples = valid_df.groupby('ships').apply(lambda x: x.sample(1))
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
# /tmp/ipykernel_63952/133765364.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))

# %% [markdown]
# # Submission

# %%
test_paths = np.array(os.listdir(test_image_dir))
print(len(test_paths), 'test images found')

# %%
from tqdm import tqdm

def pred_encode(img, **kwargs):
    cur_seg, _ = predict(img)
    cur_rles = multi_rle_encode(cur_seg, **kwargs)
    return [[img, rle] for rle in cur_rles if rle is not None]

out_pred_rows = []
for c_img_name in tqdm(test_paths[:30000]): ## only a subset as it takes too long to run
    out_pred_rows += pred_encode(c_img_name, min_max_threshold=1.0)

# %%
sub = pd.DataFrame(out_pred_rows)
sub.columns = ['ImageId', 'EncodedPixels']
sub = sub[sub.EncodedPixels.notnull()]
sub.head()

# %%
## let's see what we got
TOP_PREDICTIONS=5
fig, m_axs = plt.subplots(TOP_PREDICTIONS, 2, figsize = (9, TOP_PREDICTIONS*5))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2), c_img_name in zip(m_axs, sub.ImageId.unique()[:TOP_PREDICTIONS]):
    c_img = imread(os.path.join(test_image_dir, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    ax1.imshow(c_img[0])
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(masks_as_color(sub.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels']))
    ax2.set_title('Prediction')

# %%
sub1 = pd.read_csv(os.path.expanduser('~/data/airbus-ship-detection/sample_submission_v2.csv'))
sub1 = pd.DataFrame(np.setdiff1d(sub1['ImageId'].unique(), sub['ImageId'].unique(), assume_unique=True), columns=['ImageId'])
sub1['EncodedPixels'] = None
print(len(sub1), len(sub))

sub = pd.concat([sub, sub1])
print(len(sub))
sub.to_csv('submission.csv', index=False)
sub.head()
